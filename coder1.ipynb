# %%
import pandas as pd
import numpy as np
import os, json
from glob import glob

# %%
path_to_json = '2013_camera_specs/buy.net/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print(json_files)  # for me this prints ['foo.json']
# Out:
# ['5966.json', '6628.json', '6525.json', '6362.json', '5408.json', '6698.json', '6003.json', '5932.json', '6378.json', '4286.json', '5710.json', '5957.json', '6615.json', '6141.json', '5473.json', '5878.json', '6065.json', '6433.json', '6743.json', '6131.json', '5435.json', '4319.json', '6627.json', '6340.json', '6618.json', '5775.json', '4310.json', '6082.json', '5403.json', '6305.json', '5943.json', '5376.json', '4255.json', '6504.json', '6038.json', '6077.json', '6130.json', '6196.json', '5666.json', '5727.json', '5372.json', '6187.json', '6785.json', '6370.json', '6440.json', '6152.json', '5964.json', '5814.json', '6612.json', '5759.json', '6400.json', '5931.json', '5652.json', '5871.json', '6383.json', '5751.json', '5793.json', '6328.json', '6578.json', '5449.json', '6156.json', '5389.json', '6228.json', '6142.json', '6455.json', '4330.json', '6257.json', '4293.json', '5935.json', '5388.json', '6675.json', '5762.json', '5791.json', '5857.json', '6147.json', '4261.json', '5648.jso
# ...

# %%
# this finds our json files
path_to_json = '2013_camera_specs/buy.net/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

# here I define my pandas Dataframe with the columns I want to get from the json
jsons_data = pd.DataFrame(columns=['country', 'city', 'long/lat'])

# we need both the json and an index number so use enumerate()
for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        # here you need to know the layout of your json and each json has to have
        # the same structure (obviously not the structure I have here)
        country = json_text['features'][0]['properties']['country']
        city = json_text['features'][0]['properties']['name']
        lonlat = json_text['features'][0]['geometry']['coordinates']
        # here I push a list of data into a pandas DataFrame at row given by 'index'
        jsons_data.loc[index] = [country, city, lonlat]

# now that we have the pertinent json data in our DataFrame let's look at it
print(jsons_data)

# %%
def data_generator(my_path_regex):
    for filename in glob(my_path_regex):
        for json_line in open(filename, 'r'):
            yield json.loads(json_line)


my_arr = [_json for _json in data_generator('2013_camera_specs/buy.net/')]
my_arr
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-9-00f4ebdf9f19> in <module>
#       5
#       6
# ----> 7 my_arr = [_json for _json in data_generator('2013_camera_specs/buy.net/')]
#       8 my_arr
#
# <ipython-input-9-00f4ebdf9f19> in <listcomp>(.0)
#       5
#       6
# ----> 7 my_arr = [_json for _json in data_generator('2013_camera_specs/buy.net/')]
#       8 my_arr
#
# <ipython-input-9-00f4ebdf9f19> in data_generator(my_path_regex)
#       1 def data_generator(my_path_regex):
#       2     for filename in glob(my_path_regex):
# ----> 3         for json_line in open(filename, 'r'):
#       4             yield json.loads(json_line)
#       5
#
# IsADirectoryError: [Errno 21] Is a directory: '2013_camera_specs/buy.net/'

# %%
df = pd.read_json
# Out:
#     index                                       <page title>    camera type  \
# 0       0  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 1       1  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 2       2  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 3       3  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 4       4  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 5       5  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 6       6  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 7       7  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 8       8  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 9       9  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
# 10     10  Datamax-O'Neil SDR Label Ribbon (24) Price Com...  Bridge Camera
#
#      depth digital zoom effective megapixels  \
# ...

# %%
import os, json
import pandas as pd
import numpy as np
import glob
pd.set_option('display.max_columns', None)

temp = pd.DataFrame()

path_to_json = '2013_camera_specs/buy.net/'

json_pattern = os.path.join(path_to_json,'*.json')
file_list = glob.glob(json_pattern)

# %%
dfs = [] # an empty list to store the data frames
for file in file_list:
    data = pd.read_json(file).drop('__unstructured', 1) # read data frame from json file
    dfs.append(data) # append the data frame to the list

temp = pd.concat(dfs, ignore_index=True) # concatenate all the data frames in the list.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5b25a68f608e> in <module>
#       1 dfs = [] # an empty list to store the data frames
#       2 for file in file_list:
# ----> 3     data = pd.read_json(file).drop('__unstructured', 1) # read data frame from json file
#       4     dfs.append(data) # append the data frame to the list
#       5
#
# ~/anaconda3/envs/siws/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~/anaconda3/envs/siws/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
# ...

# %%
df = pd.read_json('2013_camera_specs/buy.net/6429.json')
df
# Out:
#                                         <page title>  \
# 0  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 1  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 2  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 3  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 4  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 5  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 6  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 7  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 8  Kodak EasyShare V803 8 Megapixel Compact Camer...
# 9  Kodak EasyShare V803 8 Megapixel Compact Camer...
#
#               __unstructured battery builtin battery include brand name  \
# 0  Additional Specifications              No             Yes      Kodak
# 1                  Reference              No             Yes      Kodak
# 2             Compare Prices              No             Yes      Kodak
# 3                    Reviews              No             Yes      Kodak
# ...

# %%
# OFF TOPIC

# %%
import math
